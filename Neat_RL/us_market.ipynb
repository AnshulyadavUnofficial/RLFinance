# %%
from pathlib import Path
import neat, visualize
from neat.parallel import ParallelEvaluator
from pprint import pprint

from game_environment import BatchEvaluator, cache_directory_files

# %%
def add_file():
    if len(working_files) == 0:
        raise ValueError("No more files in data cache")
    
    file = working_files.pop()
    data = data_cache.pop(file)
    working_cache[file] = data
    
data_dir = r"../Cirricula/Phase 1"
data_cache = cache_directory_files(data_dir,None, 1 )

working_files = list(data_cache.keys())
num_working_files = len(working_files)
working_cache = {}

# === Training hyperparameters ===
frequency            = 10    # generations per curriculum step
data_growth_factor   = 2      # double files each step
num_frequency_steps  = 10      # how many curriculum expansions
num_look_back_period = 10     # environment parameter

# %%
# === NEAT run ===
def run(config_path: Path):
    # Load NEAT configuration
    config = neat.Config(
        neat.DefaultGenome,
        neat.DefaultReproduction,
        neat.DefaultSpeciesSet,
        neat.DefaultStagnation,
        str(config_path)
    )

    # Create population and reporters
    pop = neat.Population(config)
    pop.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    pop.add_reporter(stats)
    pop.add_reporter(neat.Checkpointer(frequency))

    # Instantiate vectorized evaluator (no ParallelEvaluator)
    evaluator = BatchEvaluator(working_cache, num_look_back_period)

    winner = None
    files_to_add = 1

    # Curriculum loop
    for step in range(num_frequency_steps):
        # Expand curriculum: double files
        files_to_add = min(len(working_files), files_to_add)
        for _ in range(files_to_add):
            add_file()
        files_to_add *= data_growth_factor

        # Update evaluator's cache
        evaluator._data_cache = working_cache
        evaluator._files = list(working_cache.keys())
        print(f"Curriculum step {step}: now using {len(working_cache)} files.")

        # Run NEAT for 'frequency' generations using vectorized evaluator
        winner = pop.run(evaluator, frequency)

    # Final best genome
    print(f"\nBest genome after {num_frequency_steps*frequency} generations:\n{winner}")

    # Visualize
    visualize.draw_net(config, winner, view=False)
    visualize.plot_stats(stats, ylog=False, view=True)
    visualize.plot_species(stats, view=True)

if __name__ == "__main__":
    run(Path("./us_market_config"))
# Out:
# Curriculum step 0: now using 1 files.
#
#  ****** Running generation 0 ******
#
#          4448133 function calls (4448123 primitive calls) in 6.942 seconds
#
#    Ordered by: cumulative time
#    List reduced from 105 to 30 due to restriction <30>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.034    0.034    6.942    6.942 /Users/anshul/Documents/programming/Python/StockMarket/Neat_RL/game_environment.py:1024(call_internal)
#       380    5.179    0.014    5.186    0.014 /Users/anshul/Documents/programming/Python/StockMarket/Neat_RL/game_environment.py:1042(<listcomp>)
#         1    0.002    0.002    1.400    1.400 /Users/anshul/Documents/programming/Python/StockMarket/Neat_RL/game_environment.py:1030(<listcomp>)
#      2000    0.483    0.000    1.398    0.001 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/nn/feed_forward.py:28(create)
#      2000    0.059    0.000    0.564    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/graphs.py:58(feed_forward_layers)
#     27143    0.033    0.000    0.273    0.000 {built-in method builtins.all}
#    688000    0.257    0.000    0.262    0.000 {method 'format' of 'str' objects}
#    722000    0.240    0.000    0.240    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/graphs.py:81(<genexpr>)
#       380    0.058    0.000    0.137    0.000 /Users/anshul/Documents/programming/Python/StockMarket/Neat_RL/game_environment.py:898(step)
#      1525    0.130    0.000    0.130    0.000 {built-in method numpy.array}
#    982000    0.122    0.000    0.122    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/graphs.py:77(<genexpr>)
#      2000    0.021    0.000    0.107    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/graphs.py:27(required_for_output)
#    332000    0.072    0.000    0.072    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/graphs.py:43(<genexpr>)
# 5722/5712    0.030    0.000    0.069    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       381    0.011    0.000    0.059    0.000 /Users/anshul/Documents/programming/Python/StockMarket/Neat_RL/game_environment.py:853(_make_state)
#   1398000    0.041    0.000    0.041    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.037    0.037 /Users/anshul/Documents/programming/Python/StockMarket/Neat_RL/game_environment.py:1031(<listcomp>)
#      2000    0.037    0.000    0.037    0.000 /Users/anshul/Documents/programming/Python/StockMarket/Neat_RL/game_environment.py:757(build_cppnet)
#      2000    0.029    0.000    0.029    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/nn/feed_forward.py:33(<listcomp>)
#       762    0.000    0.000    0.026    0.000 <__array_function__ internals>:177(concatenate)
#      1143    0.000    0.000    0.017    0.000 <__array_function__ internals>:177(tile)
#      1143    0.003    0.000    0.016    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/numpy/lib/shape_base.py:1191(tile)
#       380    0.001    0.000    0.013    0.000 <__array_function__ internals>:177(argmax)
#       380    0.001    0.000    0.012    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1153(argmax)
#      2000    0.007    0.000    0.012    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/nn/feed_forward.py:6(__init__)
#      3594    0.004    0.000    0.012    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py:775(_clean_thread_parent_frames)
#       380    0.000    0.000    0.012    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#     12000    0.012    0.000    0.012    0.000 /Users/anshul/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/graphs.py:48(<genexpr>)
#       380    0.011    0.000    0.011    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#      1143    0.011    0.000    0.011    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#
#
#
# Population's average fitness: -1.28214 stdev: 0.63420
# Best fitness: -0.40669 - size: (9, 344) - species 660 - id 660
# Average adjusted fitness: 0.888
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 49>()
#      47     visualize.plot_species(stats, view=True)
#      49 if __name__ == "__main__":
# ---> 50     run(Path("./us_market_config"))
#
# Input In [3], in run(config_path)
#      36     print(f"Curriculum step {step}: now using {len(working_cache)} files.")
#      38     # Run NEAT for 'frequency' generations using vectorized evaluator
# ---> 39     winner = pop.run(evaluator, frequency)
#      41 # Final best genome
#      42 print(f"\nBest genome after {num_frequency_steps*frequency} generations:\n{winner}")
#
# File ~/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/population.py:127, in Population.run(self, fitness_function, n)
#     124         raise CompleteExtinctionException()
#     126 # Divide the new population into species.
# --> 127 self.species.speciate(self.config, self.population, self.generation)
#     129 self.reporters.end_generation(self.config, self.population, self.species)
#     131 self.generation += 1
#
# File ~/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/species.py:88, in DefaultSpeciesSet.speciate(self, config, population, generation)
#      86 for gid in unspeciated:
#      87     g = population[gid]
# ---> 88     d = distances(s.representative, g)
#      89     candidates.append((d, g))
#      91 # The new representative is the genome closest to the current representative.
#
# File ~/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/species.py:40, in GenomeDistanceCache.__call__(self, genome0, genome1)
#      37 d = self.distances.get((g0, g1))
#      38 if d is None:
#      39     # Distance is not already computed.
# ---> 40     d = genome0.distance(genome1, self.config)
#      41     self.distances[g0, g1] = d
#      42     self.distances[g1, g0] = d
#
# File ~/Documents/programming/Python/StockMarket/.venv/lib/python3.10/site-packages/neat/genome.py:433, in DefaultGenome.distance(self, other, config)
#     430         disjoint_connections += 1
#     432 for k1, c1 in iteritems(self.connections):
# --> 433     c2 = other.connections.get(k1)
#     434     if c2 is None:
#     435         disjoint_connections += 1
#
# KeyboardInterrupt:
